# %% [markdown]
# # Đề kiểm tra lập trình nhập môn phân tích dữ liệu và học sâu

# %% [markdown]
# ### Sinh viên không được phép sử dụng internet
# ### Sinh viên sau khi làm bài xong xuất ra file PDF đồng thời nộp lên Fit-lab và push lên git-hub
# ### Sinh viên làm bắt đầu làm bài từ 15h40 - 18h00

# %%
# Họ và Tên: Trần Lương Hòa
# MSSV: 2174802010453

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader, random_split
import numpy as np
from sklearn.datasets import load_iris
import matplotlib.pyplot as plt

# %%
#Bước 1: Load data
def load_dataset():
    X, y = load_iris(return_X_y=True)
    X = X[y!=2]
    y = y[y!=2]
    return X,y
#Điền ở đây
X,y = load_dataset()
print(X.shape ,y.shape )
# Out:
# (100, 4) (100,)

# %% [markdown]
# Kết quả: (100, 4) (100,)

# %%
#Trực quan hóa dữ liệu data
#Điền code ở đây
plt.scatter(X[:, 0], X[:, 1], c=y, cmap='viridis')
plt.xlabel('')
plt.ylabel('')
plt.show()

# %% [markdown]
# Kết quả

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Bước 2: Định nghĩa mô hình hồi quy logistic bằng PyTorch
class LogisticRegressTorch(nn.Module):
    def __init__(self, n_features):
        super(LogisticRegressTorch, self).__init__()
        self.linear = nn.Linear(n_features, 1)               # tạo một lớp tuyến tính (nn.Linear) với n_features đầu vào và 1 đầu ra

    def forward(self, x):
        return torch.sigmoid(self.linear(x))

# %%
# Bước 3: Định nghĩa lớp dữ liệu
class IrisTorch(Dataset):
    def __init__(self, X, y):
        self.X = torch.tensor(X, dtype=torch.float32)
        self.y = torch.tensor(y, dtype=torch.float32).unsqueeze(1)

    def __len__(self):
        return len(self.X)            #trả về số lượng mẫu trong tập dữ liệu (số lượng hàng trong self.X)

    def __getitem__(self, idx):
        return  self.X[idx], self.y[idx]            #trả về một cặp đặc trưng và nhãn tương ứng với chỉ số idx

# %%
# Tạo dữ liệu
dataset = IrisTorch(X, y)

# %%
# Bước 4: Chia tập dữ liệu thành tập huấn luyện và tập kiểm tra bằng cách chia ngẫu nhiên 70,30.
train_size = int(0.7 * len(dataset))                        #70%
test_size = len(dataset) - train_size                       #30%
train_dataset, test_dataset = random_split(dataset, [train_size, test_size])

# %%
# Tạo DataLoader
batch_size = 64
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# %%
# Bước 5: Định nghĩa criterion và optimizer
n_features = X.shape[1]
model = LogisticRegressTorch(n_features)
criterion = nn.BCELoss()
optimizer = optim.SGD(model.parameters(), lr=0.01)

# %%
# Huấn luyện mô hình
n_epochs = 100
train_losses = []
test_losses = []
test_accuracies = []

for epoch in range(n_epochs):
    model.train()
    train_loss = 0.0
    for inputs, targets in train_loader:
        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, targets)
        loss.backward()
        optimizer.step()
        train_loss += loss.item() * inputs.size(0)

    train_loss /= len(train_loader.dataset)
    train_losses.append(train_loss)

    # Đánh giá trên tập kiểm tra
    model.eval()
    test_loss = 0.0
    correct = 0
    total = 0
    with torch.no_grad():
        for inputs, targets in test_loader:
            outputs = model(inputs)
            loss = criterion(outputs, targets)
            test_loss += loss.item() * inputs.size(0)

            predicted = (outputs >= 0.5).float()
            total += targets.size(0)
            correct += (predicted == targets).sum().item()

    test_loss /= len(test_loader.dataset)
    test_losses.append(test_loss)

    accuracy = correct / total
    test_accuracies.append(accuracy)

    print(f'Epoch {epoch+1}/{n_epochs}, Train Loss: {train_loss:.4f}, Test Loss: {test_loss:.4f}, Test Accuracy: {accuracy:.4f}')
# Out:
# Epoch 1/100, Train Loss: 1.1487, Test Loss: 1.0041, Test Accuracy: 0.5000
# Epoch 2/100, Train Loss: 1.0277, Test Loss: 0.8807, Test Accuracy: 0.5000
# Epoch 3/100, Train Loss: 0.8973, Test Loss: 0.7610, Test Accuracy: 0.5000
# Epoch 4/100, Train Loss: 0.7727, Test Loss: 0.6716, Test Accuracy: 0.5000
# Epoch 5/100, Train Loss: 0.6815, Test Loss: 0.6291, Test Accuracy: 0.5000
# Epoch 6/100, Train Loss: 0.6344, Test Loss: 0.5762, Test Accuracy: 0.5000
# Epoch 7/100, Train Loss: 0.5796, Test Loss: 0.5501, Test Accuracy: 0.5000
# Epoch 8/100, Train Loss: 0.5523, Test Loss: 0.5358, Test Accuracy: 0.5000
# Epoch 9/100, Train Loss: 0.5372, Test Loss: 0.5247, Test Accuracy: 0.5000
# Epoch 10/100, Train Loss: 0.5238, Test Loss: 0.5033, Test Accuracy: 0.8333
# Epoch 11/100, Train Loss: 0.5016, Test Loss: 0.4984, Test Accuracy: 0.9333
# Epoch 12/100, Train Loss: 0.4958, Test Loss: 0.4873, Test Accuracy: 1.0000
# Epoch 13/100, Train Loss: 0.4832, Test Loss: 0.4815, Test Accuracy: 1.0000
# Epoch 14/100, Train Loss: 0.4767, Test Loss: 0.4771, Test Accuracy: 1.0000
# Epoch 15/100, Train Loss: 0.4717, Test Loss: 0.4733, Test Accuracy: 1.0000
# Epoch 16/100, Train Loss: 0.4673, Test Loss: 0.4677, Test Accuracy: 1.0000
# Epoch 17/100, Train Loss: 0.4620, Test Loss: 0.4638, Test Accuracy: 1.0000
# Epoch 18/100, Train Loss: 0.4575, Test Loss: 0.4568, Test Accuracy: 1.0000
# Epoch 19/100, Train Loss: 0.4514, Test Loss: 0.4516, Test Accuracy: 1.0000
# Epoch 20/100, Train Loss: 0.4466, Test Loss: 0.4469, Test Accuracy: 1.0000
# Epoch 21/100, Train Loss: 0.4419, Test Loss: 0.4425, Test Accuracy: 1.0000
# Epoch 22/100, Train Loss: 0.4378, Test Loss: 0.4386, Test Accuracy: 1.0000
# Epoch 23/100, Train Loss: 0.4329, Test Loss: 0.4352, Test Accuracy: 1.0000
# Epoch 24/100, Train Loss: 0.4290, Test Loss: 0.4302, Test Accuracy: 1.0000
# Epoch 25/100, Train Loss: 0.4243, Test Loss: 0.4267, Test Accuracy: 1.0000
# Epoch 26/100, Train Loss: 0.4205, Test Loss: 0.4236, Test Accuracy: 1.0000
# Epoch 27/100, Train Loss: 0.4170, Test Loss: 0.4168, Test Accuracy: 1.0000
# Epoch 28/100, Train Loss: 0.4117, Test Loss: 0.4142, Test Accuracy: 1.0000
# Epoch 29/100, Train Loss: 0.4102, Test Loss: 0.4109, Test Accuracy: 1.0000
# Epoch 30/100, Train Loss: 0.4069, Test Loss: 0.4061, Test Accuracy: 1.0000
# Epoch 31/100, Train Loss: 0.4016, Test Loss: 0.4020, Test Accuracy: 1.0000
# Epoch 32/100, Train Loss: 0.3975, Test Loss: 0.3988, Test Accuracy: 1.0000
# Epoch 33/100, Train Loss: 0.3943, Test Loss: 0.3939, Test Accuracy: 1.0000
# Epoch 34/100, Train Loss: 0.3892, Test Loss: 0.3917, Test Accuracy: 1.0000
# Epoch 35/100, Train Loss: 0.3874, Test Loss: 0.3874, Test Accuracy: 1.0000
# Epoch 36/100, Train Loss: 0.3826, Test Loss: 0.3832, Test Accuracy: 1.0000
# Epoch 37/100, Train Loss: 0.3780, Test Loss: 0.3807, Test Accuracy: 1.0000
# Epoch 38/100, Train Loss: 0.3745, Test Loss: 0.3764, Test Accuracy: 1.0000
# Epoch 39/100, Train Loss: 0.3708, Test Loss: 0.3737, Test Accuracy: 1.0000
# Epoch 40/100, Train Loss: 0.3676, Test Loss: 0.3711, Test Accuracy: 1.0000
# Epoch 72/100, Train Loss: 0.2821, Test Loss: 0.2856, Test Accuracy: 1.0000
# Epoch 73/100, Train Loss: 0.2800, Test Loss: 0.2838, Test Accuracy: 1.0000
# Epoch 74/100, Train Loss: 0.2781, Test Loss: 0.2829, Test Accuracy: 1.0000
# Epoch 75/100, Train Loss: 0.2768, Test Loss: 0.2823, Test Accuracy: 1.0000
# Epoch 76/100, Train Loss: 0.2757, Test Loss: 0.2808, Test Accuracy: 1.0000
# Epoch 77/100, Train Loss: 0.2741, Test Loss: 0.2789, Test Accuracy: 1.0000
# Epoch 78/100, Train Loss: 0.2722, Test Loss: 0.2762, Test Accuracy: 1.0000
# Epoch 79/100, Train Loss: 0.2696, Test Loss: 0.2720, Test Accuracy: 1.0000
# Epoch 80/100, Train Loss: 0.2661, Test Loss: 0.2697, Test Accuracy: 1.0000
# Epoch 81/100, Train Loss: 0.2642, Test Loss: 0.2680, Test Accuracy: 1.0000
# Epoch 82/100, Train Loss: 0.2623, Test Loss: 0.2661, Test Accuracy: 1.0000
# Epoch 83/100, Train Loss: 0.2606, Test Loss: 0.2642, Test Accuracy: 1.0000
# Epoch 84/100, Train Loss: 0.2592, Test Loss: 0.2624, Test Accuracy: 1.0000
# Epoch 85/100, Train Loss: 0.2573, Test Loss: 0.2608, Test Accuracy: 1.0000
# Epoch 86/100, Train Loss: 0.2558, Test Loss: 0.2589, Test Accuracy: 1.0000
# Epoch 87/100, Train Loss: 0.2536, Test Loss: 0.2572, Test Accuracy: 1.0000
# Epoch 88/100, Train Loss: 0.2521, Test Loss: 0.2555, Test Accuracy: 1.0000
# Epoch 89/100, Train Loss: 0.2501, Test Loss: 0.2538, Test Accuracy: 1.0000
# Epoch 90/100, Train Loss: 0.2487, Test Loss: 0.2528, Test Accuracy: 1.0000
# Epoch 91/100, Train Loss: 0.2469, Test Loss: 0.2515, Test Accuracy: 1.0000
# Epoch 92/100, Train Loss: 0.2457, Test Loss: 0.2514, Test Accuracy: 1.0000
# Epoch 93/100, Train Loss: 0.2449, Test Loss: 0.2494, Test Accuracy: 1.0000
# Epoch 94/100, Train Loss: 0.2431, Test Loss: 0.2479, Test Accuracy: 1.0000
# Epoch 95/100, Train Loss: 0.2415, Test Loss: 0.2457, Test Accuracy: 1.0000
# Epoch 96/100, Train Loss: 0.2395, Test Loss: 0.2439, Test Accuracy: 1.0000
# Epoch 97/100, Train Loss: 0.2380, Test Loss: 0.2437, Test Accuracy: 1.0000
# Epoch 98/100, Train Loss: 0.2372, Test Loss: 0.2402, Test Accuracy: 1.0000
# Epoch 99/100, Train Loss: 0.2344, Test Loss: 0.2387, Test Accuracy: 1.0000
# Epoch 100/100, Train Loss: 0.2329, Test Loss: 0.2374, Test Accuracy: 1.0000

# %%
# Vẽ biểu đồ loss và accuracy
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(train_losses, label='Train Loss')
plt.plot(test_losses, label='Test Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.title('Loss over Epochs')

# Vẽ biểu đồ accuracy
plt.subplot(1, 2, 2)
plt.plot(test_accuracies, label='Test Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.title('Accuracy over Epochs')

plt.show()

# %% [markdown]
# #Kết quả:

# %% [markdown]
# ![image.png](attachment:image.png)
